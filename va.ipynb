# %%
pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in /Users/neelu/clear/lib/python3.10/site-packages (23.3.1)
# Collecting pip
#   Using cached pip-23.3.2-py3-none-any.whl.metadata (3.5 kB)
# Using cached pip-23.3.2-py3-none-any.whl (2.1 MB)
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 23.3.1
#     Uninstalling pip-23.3.1:
#       Successfully uninstalled pip-23.3.1
# Successfully installed pip-23.3.2
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install SpeechRecognition pyttsx3
# Out:
# Requirement already satisfied: SpeechRecognition in /Users/neelu/clear/lib/python3.10/site-packages (3.10.1)
# Requirement already satisfied: pyttsx3 in /Users/neelu/clear/lib/python3.10/site-packages (2.90)
# Requirement already satisfied: requests>=2.26.0 in /Users/neelu/clear/lib/python3.10/site-packages (from SpeechRecognition) (2.31.0)
# Requirement already satisfied: typing-extensions in /Users/neelu/clear/lib/python3.10/site-packages (from SpeechRecognition) (4.8.0)
# Requirement already satisfied: pyobjc>=2.4 in /Users/neelu/clear/lib/python3.10/site-packages (from pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-core==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-AddressBook==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-AppleScriptKit==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-ApplicationServices==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-Automator==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-CFNetwork==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-Cocoa==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-CoreAudio==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-CoreAudioKit==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-CoreData==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-CoreMIDI==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-CoreServices==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-CoreText==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-DiscRecording==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-DiscRecordingUI==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-DiskArbitration==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-DVDPlayback==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-ExceptionHandling==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-InstallerPlugins==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-IOBluetooth==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-IOBluetoothUI==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-LatentSemanticMapping==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-LaunchServices==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-OSAKit==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-PreferencePanes==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-Quartz==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-ScreenSaver==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-Security==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-SecurityFoundation==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-SecurityInterface==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-SearchKit==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-SyncServices==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-SystemConfiguration==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-WebKit==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-AppleScriptObjC==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-CoreLocation==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-CoreWLAN==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-ImageCaptureCore==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-IOSurface==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-NetFS==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-OpenDirectory==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-ServiceManagement==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-iTunesLibrary==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-AVFoundation==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-CoreMedia==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-CoreMediaIO==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-StoreKit==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-SceneKit==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-libdispatch==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-libxpc==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-AudioVideoBridging==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-Accounts==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-EventKit==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-GameCenter==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-Social==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-GameKit==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-VideoToolbox==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-AVKit==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-GameController==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-MapKit==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-MediaAccessibility==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-MediaLibrary==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-MediaToolbox==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-SpriteKit==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-CloudKit==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-CoreBluetooth==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-CryptoTokenKit==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-FinderSync==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-LocalAuthentication==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-MultipeerConnectivity==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-NotificationCenter==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-Contacts==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-ContactsUI==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-Metal==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-MetalKit==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-ModelIO==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-NetworkExtension==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-Photos==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-PhotosUI==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-GameplayKit==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-Intents==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-MediaPlayer==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-SafariServices==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-ColorSync==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-CoreML==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-CoreSpotlight==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-ExternalAccessory==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-MetalPerformanceShaders==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-Vision==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-AdSupport==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-BusinessChat==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-NaturalLanguage==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-Network==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-UserNotifications==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-VideoSubscriberAccount==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-AuthenticationServices==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-AutomaticAssessmentConfiguration==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-CoreHaptics==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-CoreMotion==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-DeviceCheck==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-ExecutionPolicy==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-FileProvider==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-FileProviderUI==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-LinkPresentation==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-OSLog==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-PencilKit==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-PushKit==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-QuickLookThumbnailing==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-Speech==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-SoundAnalysis==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-SystemExtensions==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-Accessibility==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-AdServices==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-AppTrackingTransparency==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-CallKit==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-ClassKit==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-KernelManagement==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-MetalPerformanceShadersGraph==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-MLCompute==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-PassKit==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-ReplayKit==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-ScreenTime==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-UniformTypeIdentifiers==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-UserNotificationsUI==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-Virtualization==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-DataDetection==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-IntentsUI==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-LocalAuthenticationEmbeddedUI==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-MailKit==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-MetricKit==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-PHASE==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-ShazamKit==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-ScreenCaptureKit==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-AVRouting==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-BackgroundAssets==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-ExtensionKit==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-HealthKit==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-MetalFX==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-SafetyKit==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-SharedWithYouCore==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-SharedWithYou==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-ThreadNetwork==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-Cinematic==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-SensitiveContentAnalysis==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-Symbols==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-CalendarStore==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-Collaboration==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-DictionaryServices==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-FSEvents==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-InputMethodKit==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-InstantMessage==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: pyobjc-framework-ScriptingBridge==10.1 in /Users/neelu/clear/lib/python3.10/site-packages (from pyobjc>=2.4->pyttsx3) (10.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/neelu/clear/lib/python3.10/site-packages (from requests>=2.26.0->SpeechRecognition) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/neelu/clear/lib/python3.10/site-packages (from requests>=2.26.0->SpeechRecognition) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/neelu/clear/lib/python3.10/site-packages (from requests>=2.26.0->SpeechRecognition) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/neelu/clear/lib/python3.10/site-packages (from requests>=2.26.0->SpeechRecognition) (2023.11.17)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in /Users/neelu/clear/lib/python3.10/site-packages (4.12.2)
# Requirement already satisfied: soupsieve>1.2 in /Users/neelu/clear/lib/python3.10/site-packages (from beautifulsoup4) (2.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
import speech_recognition as sr
import pyttsx3
import datetime
import os
from bs4 import BeautifulSoup
import objc

# %%
# Initialize the speech recognition and text-to-speech engine
engine = pyttsx3.init()
r = sr.Recognizer()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/clear/lib/python3.10/site-packages/pyttsx3/__init__.py:20, in init(driverName, debug)
#      19 try:
# ---> 20     eng = _activeEngines[driverName]
#      21 except KeyError:
#
# File ~/clear/lib/python3.10/weakref.py:137, in WeakValueDictionary.__getitem__(self, key)
#     136     self._commit_removals()
# --> 137 o = self.data[key]()
#     138 if o is None:
#
# KeyError: None
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 2
#       1 # Initialize the speech recognition and text-to-speech engine
# ----> 2 engine = pyttsx3.init()
#       3 r = sr.Recognizer()
#
# File ~/clear/lib/python3.10/site-packages/pyttsx3/__init__.py:22, in init(driverName, debug)
#      20     eng = _activeEngines[driverName]
#      21 except KeyError:
# ---> 22     eng = Engine(driverName, debug)
#      23     _activeEngines[driverName] = eng
#      24 return eng
#
# File ~/clear/lib/python3.10/site-packages/pyttsx3/engine.py:30, in Engine.__init__(self, driverName, debug)
#      20 def __init__(self, driverName=None, debug=False):
#      21     """
#      22     Constructs a new TTS engine instance.
#      23
#    (...)
#      28     @type debug: bool
#      29     """
# ---> 30     self.proxy = driver.DriverProxy(weakref.proxy(self), driverName, debug)
#      31     # initialize other vars
#      32     self._connects = {}
#
# File ~/clear/lib/python3.10/site-packages/pyttsx3/driver.py:50, in DriverProxy.__init__(self, engine, driverName, debug)
#      48 # import driver module
#      49 name = 'pyttsx3.drivers.%s' % driverName
# ---> 50 self._module = importlib.import_module(name)
#      51 # build driver instance
#      52 self._driver = self._module.buildDriver(weakref.proxy(self))
#
# File ~/clear/lib/python3.10/importlib/__init__.py:126, in import_module(name, package)
#     124             break
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1050, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1027, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1006, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:688, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:883, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:241, in _call_with_frames_removed(f, *args, **kwds)
#
# File ~/clear/lib/python3.10/site-packages/pyttsx3/drivers/nsss.py:12
#       8 def buildDriver(proxy):
#       9     return NSSpeechDriver.alloc().initWithProxy(proxy)
# ---> 12 class NSSpeechDriver(NSObject):
#      13     @objc.python_method
#      14     def initWithProxy(self, proxy):
#      15         self = super(NSSpeechDriver, self).init()
#
# File ~/clear/lib/python3.10/site-packages/pyttsx3/drivers/nsss.py:13, in NSSpeechDriver()
#      12 class NSSpeechDriver(NSObject):
# ---> 13     @objc.python_method
#      14     def initWithProxy(self, proxy):
#      15         self = super(NSSpeechDriver, self).init()
#      16         if self:
#
# NameError: name 'objc' is not defined
